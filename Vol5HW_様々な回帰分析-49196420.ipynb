# %% [markdown]
# # 様々な回帰手法の実践

# %% [markdown]
# scikit-learnのbostonデータセットを用いた重回帰、多項式回帰の実践を行う

# %%
# ライブラリのインポート
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# bostonデータのインスタンス生成
from sklearn.datasets import load_boston
boston = load_boston()

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
#説明変数→さきほどの変数の中のNEDV以外
boston.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
#目的変数→住宅価格の中央値（NEDV）、最初の50個を出力
boston.target[:50]
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4])

# %% [markdown]
# ## データの観察

# %%
# PandasのDataFrame型に変換
df_data = pd.DataFrame(boston.data, columns=boston.feature_names)
df_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# 目的変数もDataFrameに変換
df_target = pd.DataFrame(boston.target, columns=['MEDV'])
df_target.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
# 説明変数と目的変数のDataFrameを結合する
df = pd.concat([df_data, df_target], axis=1)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# 基本統計量の出力
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# 散布図行列を出力（時間がかかります）
import seaborn as sns
sns.pairplot(df, height=2.0)
plt.show()

# %%
# 相関係数行列
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# ヒートマップの表示
plt.figure(figsize=(12, 9))
# annot：数値を表示するか
# square：正方形で表示するか
# fmt：表示する数値の型（.2f→float型で小数点以下２桁表示）
sns.heatmap(df.corr(), annot=True, square=True, fmt='.2f')
plt.show()

# %% [markdown]
# 今回はLSTATとRMの説明変数を用いて重回帰分析を行う

# %% [markdown]
# ## 前処理

# %%
# DataFrameの.valuesメソッドでarrayに変換
X = df.loc[:, ['LSTAT', 'RM']].values
X
# Out:
# array([[4.98 , 6.575],
#        [9.14 , 6.421],
#        [4.03 , 7.185],
#        ...,
#        [5.64 , 6.976],
#        [6.48 , 6.794],
#        [7.88 , 6.03 ]])

# %%
y = df.loc[:, ['MEDV']].values
y[:10]
# Out:
# array([[24. ],
#        [21.6],
#        [34.7],
#        [33.4],
#        [36.2],
#        [28.7],
#        [22.9],
#        [27.1],
#        [16.5],
#        [18.9]])

# %%
# ホールド・アウト法によるデータの分割（今回はtestを２割とする）
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# 分割されたデータの個数を確認
print(X.shape)
print(y.shape)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (506, 2)
# (506, 1)
# (404, 2)
# (404, 1)
# (102, 2)
# (102, 1)

# %% [markdown]
# ## 重回帰モデル

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# /Users/xiafei/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py:533: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   linalg.lstsq(X, y)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# 関数の係数を出力
lr.intercept_
# Out:
# array([-1.26252868])

# %%
lr.coef_
# Out:
# array([[-0.65494879,  5.10906846]])

# %% [markdown]
# 重回帰モデルは以下の関数となる
# $$y = -1.26 - 0.655x_1 + 5.11x_2$$

# %% [markdown]
# ## モデルの評価

# %%
# 決定係数：データのモデルへの当てはまりの良さ
print('train: %.3f' % lr.score(X_train, y_train))
print('test : %.3f' % lr.score(X_test, y_test))
# Out:
# train: 0.662
# test : 0.541

# %%
# mpl_toolkitsを用いて3次元の描画する
from mpl_toolkits.mplot3d import Axes3D

ax = Axes3D(plt.figure(figsize=(8, 5)))

# (x, y , z)
ax.scatter3D(df['LSTAT'], df['RM'], df['MEDV'])

# 関数の指定
X_grid, Y_grid = np.meshgrid(np.arange(0, 40, 2.5), np.arange(1, 10, 0.5))
w0 = lr.intercept_
w1 = lr.coef_[0, 0]
w2 = lr.coef_[0, 1]
Z = w0 + w1*X_grid + w2*Y_grid

# 平面の描画
ax.plot_wireframe(X_grid, Y_grid, Z, alpha=0.3, color='red')

# ラベル
ax.set_xlabel('LSTAT')
ax.set_ylabel('RM')
ax.set_zlabel('MEDV')

plt.show()

# %% [markdown]
# # 多項式回帰

# %%
lstat = df.loc[:, ['LSTAT']].values
rm = df.loc[:, ['RM']].values
y = df.loc[:, ['MEDV']].values

# %%
from sklearn.model_selection import train_test_split
lstat_train, lstat_test, y_train, y_test = train_test_split(lstat, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## 単回帰

# %%
from sklearn.linear_model import LinearRegression
model_lin = LinearRegression()
model_lin.fit(lstat_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# データの散布図表示
plt.scatter(lstat, y, color='lightgray', label='data')
x = np.arange(0, 40, 1)[:, np.newaxis]

# 直線の描画
plt.plot(x, model_lin.predict(x), color='red', label='linear')
# ラベルを表示
plt.xlabel('LSTAT')
plt.ylabel('MEDV')

# 凡例
plt.legend(loc = 'upper right')

plt.show()

# %% [markdown]
# ## 多項式回帰

# %%
# 変数変換
from sklearn.preprocessing import PolynomialFeatures
quad = PolynomialFeatures(degree=2)
lstat_quad = quad.fit_transform(lstat)
lstat_quad
# Out:
# array([[ 1.    ,  4.98  , 24.8004],
#        [ 1.    ,  9.14  , 83.5396],
#        [ 1.    ,  4.03  , 16.2409],
#        ...,
#        [ 1.    ,  5.64  , 31.8096],
#        [ 1.    ,  6.48  , 41.9904],
#        [ 1.    ,  7.88  , 62.0944]])

# %%
## データの分割
lstat_quad_train, lstat_quad_test, y_train, y_test = train_test_split(lstat_quad, y, test_size = 0.2, random_state = 0)

# %%
model_quad = LinearRegression()
model_quad.fit(lstat_quad_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#データの散布図を表示
plt.scatter(lstat, y, color='lightgray', label='data')

# 直線の描画
plt.plot(x, model_lin.predict(x), color='red', label='linear')

# 変数変換する
x_quad = quad.fit_transform(x)

# 回帰曲線を表示（2次関数）
plt.plot(x, model_quad.predict(x_quad), color='green', label='quad')

# ラベルを表示
plt.xlabel('LSTAT')
plt.ylabel('MEDV')

# 凡例を表示
plt.legend(loc = 'upper right')

# 上記の内容でグラフを表示
plt.show()

# %% [markdown]
# ## ３次関数での多項式回帰

# %%
# 変数変換

cubic = PolynomialFeatures(degree=3)

lstat_cubic = cubic.fit_transform(lstat)
lstat_cubic
# Out:
# array([[  1.      ,   4.98    ,  24.8004  , 123.505992],
#        [  1.      ,   9.14    ,  83.5396  , 763.551944],
#        [  1.      ,   4.03    ,  16.2409  ,  65.450827],
#        ...,
#        [  1.      ,   5.64    ,  31.8096  , 179.406144],
#        [  1.      ,   6.48    ,  41.9904  , 272.097792],
#        [  1.      ,   7.88    ,  62.0944  , 489.303872]])

# %%
#データ分割
lstat_cubic_train, lstat_cubic_test, _, _ = train_test_split(lstat_cubic, y, test_size = 0.2, random_state = 0)

# %%
#モデルの学習
model_cubic = LinearRegression()
model_cubic.fit(lstat_cubic_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(lstat, y, color='lightgray', label='data') 
plt.plot(x, model_lin.predict(x), color='red', label='linear')
plt.plot(x, model_quad.predict(x_quad), color='green', label='quad')
x_cubic = cubic.fit_transform(x)
plt.plot(x, model_cubic.predict(x_cubic), color='blue', label='cubic')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# ### レポート課題

# %% [markdown]
# #### （１）上記のモデルを３パターン以上それぞれ決定係数を算出してください。

# %%
# 線形回帰
# print(model_lin.intercept_, model_lin.coef_)
res_lstat_train = model_lin.score(lstat_train, y_train)
res_lstat_test = model_lin.score(lstat_test, y_test)
print('train: %.3f' % res_lstat_train)
print('test : %.3f' % res_lstat_test)

from sklearn.metrics import r2_score
# print('R^2 train: %.3f, test: %.3f' %(r2_score(y_train, model_lin.predict(lstat_train)),r2_score(y_test, model_lin.predict(lstat_test))))

# 2次関数
# print(model_quad.intercept_, model_quad.coef_)
res_model_quad_train = model_quad.score(lstat_quad_train, y_train)
res_lstat_quad_test = model_quad.score(lstat_quad_test, y_test)
print('train: %.3f' % res_model_quad_train)
print('test : %.3f' % res_lstat_quad_test)

# print('R^2 train: %.3f, test: %.3f' %(r2_score(y_train, model_quad.predict(lstat_quad_train)),r2_score(y_test, model_quad.predict(lstat_quad_test))))

# 3次関数
# print(model_cubic.intercept_, model_cubic.coef_)
res_lstat_cubic_train = model_cubic.score(lstat_cubic_train, y_train)
res_lstat_cubic_test = model_cubic.score(lstat_cubic_test, y_test)
print('train: %.3f' % res_lstat_cubic_train)
print('test : %.3f' % res_lstat_cubic_test)

# print('R^2 train: %.3f, test: %.3f' %(r2_score(y_train, model_cubic.predict(lstat_cubic_train)),r2_score(y_test, model_cubic.predict(lstat_cubic_test))))

# それ以外でも試したいものがあればご自由に
ten = PolynomialFeatures(degree=10)
lstat_ten = ten.fit_transform(lstat)
lstat_ten_train, lstat_ten_test, _, _ = train_test_split(lstat_ten, y, test_size = 0.2, random_state = 0)
model_ten = LinearRegression()
model_ten.fit(lstat_ten_train, y_train)

plt.scatter(lstat, y, color='lightgray', label='data') 
plt.plot(x, model_lin.predict(x), color='red', label='linear')
plt.plot(x, model_quad.predict(x_quad), color='green', label='quad')
plt.plot(x, model_cubic.predict(x_cubic), color='blue', label='cubic')

x_ten = ten.fit_transform(x)
plt.plot(x, model_ten.predict(x_ten), color='black', label='ten')

plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.legend(loc = 'upper right')
plt.show()

res_lstat_ten_train = model_ten.score(lstat_ten_train, y_train)
res_lstat_ten_test = model_ten.score(lstat_ten_test, y_test)
print('train: %.3f' % res_lstat_ten_train)
print('test : %.3f' % res_lstat_ten_test)

# print('R^2 train: %.3f, test: %.3f' %(r2_score(y_train, model_ten.predict(lstat_ten_train)),r2_score(y_test, model_ten.predict(lstat_ten_test))))
# Out:
# train: 0.571
# test : 0.431
# train: 0.669
# test : 0.523
# train: 0.685
# test : 0.543
# train: 0.709
# test : 0.497

# %% [markdown]
# #### （２）LSTATを用いたMEDVの予測に関して用いるモデルを選び、その数式を記せ。# 線形回帰

# %%
# 定数項の出力（.intercept_と.coef_を用いる）
# 3次関数
print(model_cubic.intercept_, model_cubic.coef_)
# Out:
# [48.86900118] [[ 0.00000000e+00 -3.91539295e+00  1.52029855e-01 -2.07252738e-03]]

# %% [markdown]
# 数式の記述（例）
# $$y = -1.26 - 0.655x_1 + 5.11x_2$$
# 3次関数の数式：
# $$y = 48.869 - 3.915x_2 + 0.152x_3 - 0.002x_4$$

# %% [markdown]
# #### （３）モデルを選んだ理由とその根拠を述べよ。（評価指標や可視化の結果などを基に述べると良い）

# %% [markdown]
# （日本語で100文字以上：English:200 char over）

# %% [markdown]
# As the degree grows, the model goes from underfitting to overfitting.
# underfitting: The mathcing is not well, and the data is far from the fitting curve.
# Overfitting: It seems to fit almost every data, but the law of information is lost. As shown in the figure, when LSTAT > 30, the curve drops seriously.
#
# Comparing the above models, I think the "3次関数" is better. The first model is underfitting and the last model which degree=10 is overfitting. Comparing the second(quard) and third(cubic) models, the second model starts to rise in the 25-40 LSTAT, which is not in line with the actual situation, so I choose the third model.
#
# It’s important to choose the right features, sometimes, removing the unwanted feature is also feature engineering. As the feature which is not related degrade the performance of the model.
